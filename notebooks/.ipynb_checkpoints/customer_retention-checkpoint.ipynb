# %% [markdown]
# # Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Load Dataset

# %%
file_path = '../data/customer_retention.xlsx'
df = pd.read_excel(file_path)

# %% [markdown]
# # Step 3: Basic Information and Overview

# %%
print(df.shape)  # Rows and Columns
print(df.info())  # Data types and non-null counts
print(df.describe())  # Statistical summary
print(df.isnull().sum()) # Catch missing values
# Out:
# (100000, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   CustomerID                   100000 non-null  object
#  1   Name                         100000 non-null  object
#  2   Email                        100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Gender                       100000 non-null  object
#  5   City                         100000 non-null  object
#  6   SignupDate                   100000 non-null  datetime64[ns]
#  7   LastPurchaseDate             100000 non-null  datetime64[ns]
#  8   TotalPurchases               100000 non-null  int64
#  9   TotalSpent                   100000 non-null  float64
#  10  CustomerSegment              100000 non-null  object
#  11  ProductCategoriesPurchased   100000 non-null  object
#  12  CustomerSupportInteractions  100000 non-null  int64
#  13  AverageBasketValue           100000 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(7)
# memory usage: 10.7+ MB
# None
#                  Age                     SignupDate  \
# count  100000.000000                         100000
# mean       30.130350  2024-02-27 10:48:06.048000512
# min        18.000000            2023-05-29 00:00:00
# 25%        23.000000            2023-10-14 00:00:00
# 50%        30.000000            2024-02-27 00:00:00
# 75%        36.000000            2024-07-14 00:00:00
# max        60.000000            2024-11-28 00:00:00
# std         8.907949                            NaN
#
#                  LastPurchaseDate  TotalPurchases     TotalSpent  \
# count                      100000   100000.000000  100000.000000
# mean   2025-02-26 02:13:14.592000        5.998900    3004.828600
# min           2024-11-29 00:00:00        0.000000      28.490000
# 25%           2025-01-12 00:00:00        4.000000    1616.012500
# 50%           2025-02-26 00:00:00        6.000000    2621.850000
# 75%           2025-04-12 00:00:00        8.000000    3980.707500
# max           2025-05-27 00:00:00       19.000000   21296.000000
# std                           NaN        2.448881    1898.877953
#
#        CustomerSupportInteractions  AverageBasketValue
# count                100000.000000       100000.000000
# mean                      1.802800          630.890728
# min                       0.000000            3.170000
# 25%                       1.000000          264.180000
# 50%                       2.000000          460.615000
# 75%                       3.000000          777.592500
# max                      10.000000        14457.860000
# std                       1.340526          639.873140
# CustomerID                     0
# Name                           0
# Email                          0
# Age                            0
# Gender                         0
# City                           0
# SignupDate                     0
# LastPurchaseDate               0
# TotalPurchases                 0
# TotalSpent                     0
# CustomerSegment                0
# ProductCategoriesPurchased     0
# CustomerSupportInteractions    0
# AverageBasketValue             0
# dtype: int64

# %% [markdown]
# # Step 4: Clean Column Names (optional step)

# %%
#df.columns = df.columns.str.strip().str.replace(' ', '_')

# %% [markdown]
# # Step 5: Strip whitespace and fix casing

# %%
df['Gender'] = df['Gender'].str.strip().str.title()
df['CustomerSegment'] = df['CustomerSegment'].str.strip().str.title()
df['City'] = df['City'].str.strip().str.title()

# %% [markdown]
# # Step 6: Convert Date Columns to Datetime Format

# %%
df["LastPurchaseDate"] = pd.to_datetime(df["LastPurchaseDate"], errors='coerce')
df["SignupDate"] = pd.to_datetime(df["SignupDate"], errors='coerce')

# %% [markdown]
# # Step 7: Days Since Last Purchase

# %%
current_date  = pd.to_datetime("2025-05-28")
df["DaysSinceLastPurchase"] = (current_date  - df["LastPurchaseDate"]).dt.days

# %% [markdown]
# # Step 8: Customer By Age Group

# %%
df["CustomerAgeGroup"] = pd.cut(df["Age"], bins=[17,25,35,50,70], labels=["18-25", "26-35", "36-50", "51+"])

# %% [markdown]
# # Step 9: Average Basket Value

# %%
#Replace those zeros with NaN
df.loc[df["TotalPurchases"] == 0, "TotalPurchases"] = np.nan

df["AverageBasketValue_Calculated"] = (df["TotalSpent"] / df["TotalPurchases"]).round(2)

# %% [markdown]
# # Step 10: Check for Outliers EX- customers with extremely high spend

# %%
outliers = df[df["TotalSpent"] > df["TotalSpent"].quantile(0.99)]
print("Top spenders:")
print(outliers[["CustomerID", "TotalSpent", "CustomerSegment"]].head())
# Out:
# Top spenders:
#      CustomerID  TotalSpent CustomerSegment
# 99   CUST100099    10685.21         Regular
# 181  CUST100181    10172.87        One-Time
# 303  CUST100303     9091.02             Vip
# 317  CUST100317     9253.97         Regular
# 324  CUST100324    10169.06             Vip

# %% [markdown]
# # Step 11: CustomerTenure

# %%
current_date = pd.to_datetime("2025-05-28")
df["CustomerTenure"] = (current_date - df["SignupDate"]).dt.days

# %% [markdown]
# # Step 12:  Final Check

# %%
df.describe(include='all')
df.head()
# Out:
#    CustomerID             Name                      Email  Age  Gender  \
# 0  CUST100000  Angela Williams   tylerrussell@example.com   37    Male
# 1  CUST100001     Isaiah Miles  lisagutierrez@example.com   37    Male
# 2  CUST100002   Amy Washington     hallangela@example.com   23  Female
# 3  CUST100003  Kristen Wiggins   leonarddavid@example.com   31  Female
# 4  CUST100004     Paula Newton          roy91@example.com   34  Female
#
#         City SignupDate LastPurchaseDate  TotalPurchases  TotalSpent  \
# 0      Delhi 2023-07-16       2025-05-10             7.0     4283.53
# 1     Mumbai 2024-05-24       2024-12-03            10.0     2580.12
# 2  Hyderabad 2024-07-20       2024-12-04             5.0     2028.39
# 3  Bangalore 2024-02-24       2025-04-11             5.0     3249.06
# 4    Chennai 2023-08-29       2025-02-19             6.0      748.08
#
#   CustomerSegment ProductCategoriesPurchased  CustomerSupportInteractions  \
# 0         Regular        Beauty, Electronics                            1
# 1        One-Time         Books, Electronics                            2
# 2         Regular          Books, Toys, Home                            2
# 3        One-Time         Electronics, Books                            1
# 4         Regular                      Books                            3
#
#    AverageBasketValue  DaysSinceLastPurchase CustomerAgeGroup  \
# 0              611.93                     18            36-50
# 1              258.01                    176            36-50
# 2              405.68                    175            18-25
# 3              649.81                     47            26-35
# 4              124.68                     98            26-35
#
#    AverageBasketValue_Calculated  CustomerTenure
# 0                         611.93             682
# 1                         258.01             369
# 2                         405.68             312
# 3                         649.81             459
# 4                         124.68             638

# %% [markdown]
# # Save to CSV

# %%
df.to_csv('customer_retention_V2.csv', index=False)
print("✅ File saved as 'customer_retention_V2.csv'")
# Out:
# ✅ File saved as 'customer_retention_V2.csv'

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # 1: Customer Distribution by Segment

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='CustomerSegment', hue='CustomerSegment', palette='Set2', legend=False)
plt.title('Customer Count by Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2: Gender Distribution

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gender' , hue='CustomerSegment', palette='Set2')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# # 3: Age Group Distribution

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='CustomerAgeGroup', hue='CustomerAgeGroup', order=["18-25", "26-35", "36-50", "51+"], palette='Set2', legend=False)
plt.title('Customer Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4: Top Cities by Customer Count

# %%
plt.figure(figsize=(10, 5))
top_cities = df['City'].value_counts().nlargest(10)

top_cities_df = top_cities.reset_index()
top_cities_df.columns = ['City', 'Count']

# Assign `City` also as `hue` and disable the legend to keep it clean
sns.barplot(data=top_cities_df, x='City', y='Count', hue='City', palette='Set2', dodge=False, legend=False)

plt.title('Top 10 Cities by Customer Count')
plt.xlabel('City')
plt.ylabel('Customers')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5: Total Spend by Segment (Boxplot)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='CustomerSegment', y='TotalSpent', hue='CustomerSegment', palette='Set2', dodge=False, legend=False)
plt.title('Spending Distribution by Customer Segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6: Purchases vs Spending (Scatter)

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='TotalPurchases', y='TotalSpent', hue='CustomerSegment', palette='deep')
plt.title('Total Purchases vs Total Spent')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7: Average Basket Value by Segment

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='CustomerSegment', y='AverageBasketValue',  hue='CustomerSegment', palette='Set2')
plt.title('Basket Value by Segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8: Customer Tenure Distribution

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['CustomerTenure'], kde=True, bins=30, color='coral')
plt.title('Customer Tenure Distribution (days)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9: Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
numeric_df = df.select_dtypes(include=['float', 'int'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- ### 🎯 Key Takeaways
# - Majority customers are in the 'Regular' segment.
# - Top cities: Delhi, Mumbai, Bangalore.
# - 25–34 age group dominates.
# - Higher purchases usually result in higher spending.
# - VIPs spend more per basket. -->

# %% [markdown]
# # Key Takeaways
# - Majority customers are in the 'Regular' segment.
# - Top cities: Delhi, Mumbai, Bangalore.
# - 25–34 age group dominates.
# - Higher purchases usually result in higher spending.
# - VIPs spend more per basket.
